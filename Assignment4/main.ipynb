# %%
import numpy as np
import code1
import matplotlib.pyplot as plt
import multiclass
# %matplotlib inline

# %%
A=[]
A=code1.read_file(A,"Class1.txt")
A=code1.read_file(A,"Class2.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W,convergence=code1.train(A,Y)      
print("Final Weights: ",W)
code1.plot_decision_boundry(A,Y,W)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  2
# Final Weights:  [[10.02203429]
#  [-0.42376431]
#  [ 1.74566406]]
# (1600170, 2)
# size of z (1430, 1119)

# %%
A=[]
A=code1.read_file(A,"Class1.txt")
A=code1.read_file(A,"Class3.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W,convergence=code1.train(A,Y)      
print("Final Weights: ",W)
code1.plot_decision_boundry(A,Y,W)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  98
# Final Weights:  [[144.70547739]
#  [-13.79086435]
#  [  8.25395889]]
# (1877898, 2)
# size of z (1221, 1538)

# %%
A=[]
A=code1.read_file(A,"Class2.txt")
A=code1.read_file(A,"Class3.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W,convergence=code1.train(A,Y)      
print("Final Weights: ",W)
code1.plot_decision_boundry(A,Y,W)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  14
# Final Weights:  [[  0.79196088]
#  [-54.11545281]
#  [-45.83281929]]
# (1565748, 2)
# size of z (1403, 1116)

# %%
A=[]
A=code1.read_file(A,"Class1.txt")
A=code1.read_file(A,"Class2.txt")
A=code1.read_file(A,"Class3.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W1,convergence=code1.train(A,Y)      
print("Final Weights: ",W)
code1.plot_decision_boundry(A,Y,W1)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  173
# Final Weights:  [[  0.79196088]
#  [-54.11545281]
#  [-45.83281929]]
# (2199340, 2)
# size of z (1430, 1538)

# %%
A=[]
A=code1.read_file(A,"Class2.txt")
A=code1.read_file(A,"Class1.txt")
A=code1.read_file(A,"Class3.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W2,convergence=code1.train(A,Y)      
print("Final Weights: ",W2)
code1.plot_decision_boundry(A,Y,W2)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  10000
# Final Weights:  [[-441.52907392]
#  [ -81.02029525]
#  [ -96.0256124 ]]
# (2199340, 2)
# size of z (1430, 1538)

# %%
A=[]
A=code1.read_file(A,"Class3.txt")
A=code1.read_file(A,"Class2.txt")
A=code1.read_file(A,"Class1.txt")
A=np.asarray(A)
samples,features=A.shape
Y=np.zeros(len(A))
for i in range(500):
    Y[i]=1
for i in range(500,samples):
    Y[i]=-1
W3,convergence=code1.train(A,Y)      
print("Final Weights: ",W3)
code1.plot_decision_boundry(A,Y,W3)
plt.show()
code1.plot_convergence(convergence)
# Out:
# NUmber of iteration:  520
# Final Weights:  [[-464.0186725 ]
#  [  38.281328  ]
#  [  -1.21174432]]
# (2199340, 2)
# size of z (1430, 1538)

# %%
Y=np.zeros(1500)
for i in range(500):
    Y[i]=1
for i in range(500,1000):
    Y[i]=2
for i in range(1000,1500):
    Y[i]=3
multiclass.plot_decision_boundry(A,Y,W1,W2,W3)
plt.show()
# Out:
# size of z (1430, 1538)
